# %% [markdown]
# # Визуализация для предобработки

# %% [markdown]
# ## Гистограмма

# %% [markdown]
# Гистограмма показывает распределение данных. С помощью нее можно увидеть, как распределены данные, есть ли выбросы.
# Загрузим данные:

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
vis_data = pd.read_csv("train.csv",encoding = 'ISO-8859-1', low_memory = False)
vis_data.head(2)
# Out:
#    ticket_id                                     agency_name  \
# 0      22056  Buildings, Safety Engineering & Env Department
# 1      27586  Buildings, Safety Engineering & Env Department
#
#      inspector_name                      violator_name  \
# 0   Sims, Martinzie  INVESTMENT INC., MIDWEST MORTGAGE
# 1  Williams, Darrin           Michigan, Covenant House
#
#    violation_street_number violation_street_name  violation_zip_code  \
# 0                   2900.0                 TYLER                 NaN
# 1                   4311.0               CENTRAL                 NaN
#
#    mailing_address_str_number mailing_address_str_name     city  ...  \
# 0                         3.0                S. WICKER  CHICAGO  ...
# 1                      2959.0       Martin Luther King  Detroit  ...
#
#   clean_up_cost judgment_amount payment_amount balance_due  \
# 0           0.0           305.0            0.0       305.0
# 1           0.0           855.0          780.0        75.0
#
#           payment_date      payment_status collection_status grafitti_status  \
# 0                  NaN  NO PAYMENT APPLIED               NaN             NaN
# 1  2005-06-02 00:00:00        PAID IN FULL               NaN             NaN
#
#                           compliance_detail  compliance
# 0               non-compliant by no payment         0.0
# 1  compliant by late payment within 1 month         1.0
#
# [2 rows x 34 columns]

# %% [markdown]
# Один из начальных этапов работы с данных - визуализация и поиск проблем, которые можно решить. О визуализации в целом мы поговорим позже, здесь мы обсудим применение в контексте предобработки.
# Многие алгоритмы работают лучше, когда на вход принимают данные, распределенные нормально.
# Посмотрим на гистограмму какого-нибудь из признаков. Для удобства оставим только значения больше 0.
# **Совет** - на деле удаление из рассмотрения значений меньше 0 является не удобством, а необходимостью. Например, если признак обозначает выплату зарплаты, он не может быть меньше 0; тогда любые значения меньше 0 являются выбросами, мы поговорим о них чуть позже.

# %%
vis_data.balance_due[vis_data.balance_due > 0].hist(bins=100);

# %% [markdown]
# Одним из способов сделать данные более "нормальными" является взятие логарифма.
# При этом, не должно быть значений, равных 0, иначе метод `np.log` выдаст $-\infty$.

# %%
np.log(vis_data.balance_due[vis_data.balance_due > 0]).hist();

# %% [markdown]
# Другим способом является взятие квадратного корня от данных:

# %%
np.sqrt(vis_data.balance_due[vis_data.balance_due > 0]).hist();

# %% [markdown]
# Выше мы явно отсекли значения в данных, равные `0`. Если значения все-таки начинаются с `0`, перед взятием логарифма можно прибавить `1` к данным. Логарифм от `1` превратится в `0`.

# %%
np.log(vis_data.balance_due[vis_data.balance_due >= 0] + 1).hist();

# %% [markdown]
# ## Correlation plot

# %% [markdown]
# Некоторые признаки сильно скоррелированы друг с другом. Это значит, между этими признаками есть некоторая линейная зависимость. Если зависимость большая - часть скоррелированных признаков (не все) следует убрать из выборки, так как они несут избыточную информацию.
# При этом, отсутствие корреляции не означает отсутствие зависимости - между признаками в таком случае может быть сложная нелинейная зависимость.
# Для определения такой зависимости, можно посчитать матрицу корреляции для признаков и построить, например, heatmap, чтобы проще было увидеть зависимость.
# На главной диагонали этой матрицы будут стоять единицы, потому что для признака считается корреляция с самим собой.

# %%
import seaborn as sns

# %%
corr = vis_data.drop(['violation_zip_code', 'payment_amount', 
                      'clean_up_cost', 
                      'violation_street_number'], axis=1).\
                dropna(axis=1).\
                corr()
cmap = sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_9b618a18_1e87_11ea_ac20_705a0f957a43 th {
#           font-size: 7pt;
#     }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43 td {
#           padding: 0em 0em;
#     }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43 th:hover {
#           font-size: 12pt;
#     }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row0_col0 {
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row0_col1 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row0_col2 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row0_col3 {
#             background-color:  #d94563;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row0_col4 {
#             background-color:  #d8415f;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row0_col5 {
#             background-color:  #d94462;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row0_col6 {
#             background-color:  #da4966;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row1_col0 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row1_col1 {
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row1_col2 {
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row1_col3 {
#             background-color:  #eeacba;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row1_col4 {
#             background-color:  #dc526e;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row1_col5 {
#             background-color:  #f1b9c4;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row1_col6 {
#             background-color:  #eeaab7;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row2_col0 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row2_col1 {
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row2_col2 {
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row2_col3 {
#             background-color:  #eeacba;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row2_col4 {
#             background-color:  #dc526e;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row2_col5 {
#             background-color:  #f1b9c4;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row2_col6 {
#             background-color:  #eeaab7;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row3_col0 {
#             background-color:  #d83e5d;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row3_col1 {
#             background-color:  #eda7b5;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row3_col2 {
#             background-color:  #eda7b5;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row3_col3 {
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row3_col4 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row3_col5 {
#             background-color:  #477bbc;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row3_col6 {
#             background-color:  #5686c1;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row4_col0 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row4_col1 {
#             background-color:  #da4b68;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row4_col2 {
#             background-color:  #da4b68;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row4_col3 {
#             background-color:  #d73d5c;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row4_col4 {
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row4_col5 {
#             background-color:  #dc516d;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row4_col6 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row5_col0 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row5_col1 {
#             background-color:  #f0b4c0;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row5_col2 {
#             background-color:  #f0b4c0;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row5_col3 {
#             background-color:  #477bbc;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }    #T_9b618a18_1e87_11ea_ac20_705a0f957a43row5_col4 {
#             backgro
